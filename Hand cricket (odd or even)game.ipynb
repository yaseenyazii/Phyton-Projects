# %%
import random as r
print('WELCOME TO ODD OR EVEN GAME!!\n')
print("let's Start\n")
while True:
    decs=int(input('for odd press(1) for even press (2):'))
    if decs==1:
        print('you chose odd')
        break
    elif decs==2:
        print('you chose even')
        break
    else:
        print('invalid')
t1=int(input('number between 1 to 5 : '))
t2=r.randint(1,6)
print('number chose by computer',t2)
total=t1+t2
if total%2==0:
    dec=2
else:
    dec=1
if decs==dec:
    while True:
        play=int(input('For batting press(1) for balling press(2):'))
        if play==1:
            print('your batting')
            break
        elif play==2:
            print('Your bowling')
            break
        else:
            print('invalid')
else:
    play=r.randint(1,2)
    if play==1:
        print('computer chose batting')
    else:
        print('computer chose balling')

if play==1:
    runs1=0
    while True:
        r1=int(input('enter a number between 1 to 6:'))
        r2=r.randint(1,6)
        print('computer chose:',r2)
        if r1==r2:
            print('out ! your total score',runs1)
            break
        else:
            runs1=runs1+r1
    print('Your bowling')
    runs2=0
    while runs1>runs2:
        r1=int(input('enter a number between 1 to 6'))
        r2=r.randint(1,6)
        print('computer number:',r2)
        if r1==r2:
            print('out!! total score:',runs2)
            break
        else:
            runs2=runs2+r2
    if runs2<runs1:
        print('you won')
    else:
        print('you lost')
elif play==2:
    runs2=0
    while True:
        r1=int(input('enter a number between 1 to 6'))
        r2=r.randint(1,6)
        print('computer score:',r2)
        if r1==r2:
            print('out! computer total score:\n:',runs2)
            break
        else:
            runs2=runs2+r2
    print('Your batting')
    runs1=0
    while runs2>runs1:
        r1=int(input('enter a number between 1 to 6:'))
        r2=r.randint(1,6)
        print('computer number=',r2)
        if r1==r2:
            print('out!! total score:',runs1)
            break
        else:
            runs1=runs1+r1
    if runs1<runs2:
        print('you lost')
    else:
        print('you win')
# Out:
# WELCOME TO ODD OR EVEN GAME!!
#
# let's Start
#
# for odd press(1) for even press (2):1
# you chose odd
# number between 1 to 5 : 5
# number chose by computer 3
# computer chose batting
# enter a number between 1 to 6:5
# computer chose: 2
# enter a number between 1 to 6:5
# computer chose: 2
# enter a number between 1 to 6:5
# computer chose: 6
# enter a number between 1 to 6:5
# computer chose: 4
# enter a number between 1 to 6:5
# computer chose: 6
# enter a number between 1 to 6:5
# computer chose: 3
# enter a number between 1 to 6:2
# computer chose: 2
# out ! your total score 30
# Your bowling
# enter a number between 1 to 62
# computer number: 5
# enter a number between 1 to 65
# computer number: 2
# enter a number between 1 to 68
# computer number: 4
# enter a number between 1 to 66
# computer number: 1
# enter a number between 1 to 62
# computer number: 1
# enter a number between 1 to 65
# computer number: 1
# enter a number between 1 to 68
# computer number: 6
# ...
